// %%
println("hola mundo")
// Out:
// hola mundo

// %% [markdown]
// Ejercicio P1 — Ficha personal
// Declara las siguientes variables con el tipo adecuado e imprime una ficha con interpolador s:
//
// Tu nombre (texto)
// Tu edad (entero)
// Tu altura en metros (decimal)
// Si estás trabajando actualmente (booleano)
// Salida esperada (con tus datos):

// %%
val nombre = "Daniel"
val edad = 41
var trabajando = true
// Out:
// nombre: String = "Daniel"
// edad: Int = 41
// trabajando: Boolean = true

// %% [markdown]
// Ejercicio P2 — Conversor de minutos
//
// Declara una variable minutosTotales con el valor 137. Calcula y muestra cuántas horas y minutos son
//
// usando división entera y el operador módulo %.
//
// Salida esperada:
//
// 137 minutos = 2 horas y 17 minutos
//
// 💡 Recuerda: la división entre dos Int da un Int. Aquí no necesitas decimales.

// %%
var minutosTotales = 137
println(f"$minutosTotales minutos = ${minutosTotales / 60} y ${minutosTotales % 60}")
// Out:
// 137 minutos = 2 y 17
// minutosTotales: Int = 137

// %% [markdown]
// Ejercicio P1 — Clasificador de edad
//
// Declara val edad: Int = 17. Usando if/else como expresión, asigna a val categoria una de estas etiquetas y muéstrala:
//
// Menor de 0 → "edad no válida"
// 0 a 12 → "niño"
// 13 a 17 → "adolescente"
// 18 a 64 → "adulto"
// 65 o más → "senior"
// Salida esperada:
//
// Edad: 17 → adolescente
// 💡 Prueba cambiando el valor de edad a 5, 30 y 70. ¿Obtienes la categoría correcta en cada caso?

// %%
val edad: Int = 17

val categoriaEdad =
if (edad>=65) "senior"
else if (edad>=18) "adulto"
else if (edad>=13) "adolescente"
else if (edad>0) "niño"
else "edad no valida"

println(s"Edad: $edad → $categoriaEdad")
// Out:
// Edad: 17 → adolescente
// edad: Int = 17
// categoriaEdad: String = "adolescente"

// %% [markdown]
// val alumnos = List(
//   ("Ana",    8.5),
//   ("Luis",   4.2),
//   ("Marta",  9.1),
//   ("Carlos", 5.8),
//   ("Elena",  3.9),
//   ("Pedro",  7.4)
// )
//
// // Extraer solo los nombres
// val nombres = alumnos.map(_._1)
// println(s"Alumnos: ${nombres.mkString(", ")}")
//
// // Extraer solo las notas (la última expresión la muestra Almond automáticamente)
// val notas = alumnos.map(_._2)
// notas

// %%
val alumnos = List(
  ("Ana",    8.5),
  ("Luis",   4.2),
  ("Marta",  9.1),
  ("Carlos", 5.8),
  ("Elena",  3.9),
  ("Pedro",  7.4)
)
// Out:
// alumnos: List[(String, Double)] = List(
//   ("Ana", 8.5),
//   ("Luis", 4.2),
//   ("Marta", 9.1),
//   ("Carlos", 5.8),
//   ("Elena", 3.9),
//   ("Pedro", 7.4)
// )

// %%
val nombres = alumnos.map{case(nombre,nota) =>nombre }
val notas = alumnos.map{case(nombre,nota) =>nota }
println(s"Alumnos: ${nombres.mkString(", ")}")
println(s"Notas: ${notas.mkString(", ")}")
// Out:
// Alumnos: Ana, Luis, Marta, Carlos, Elena, Pedro
// Notas: 8.5, 4.2, 9.1, 5.8, 3.9, 7.4
// nombres: List[String] = List("Ana", "Luis", "Marta", "Carlos", "Elena", "Pedro")
// notas: List[Double] = List(8.5, 4.2, 9.1, 5.8, 3.9, 7.4)

// %% [markdown]
// Implementa la misma función de tres formas distintas.
//
// La función recibe un número Int y devuelve ese número multiplicado por sí mismo (al cuadrado)
//
// // 1. Con def
// ???
//
// // 2. Anónima pura — se ejecuta directamente con el valor 7
// ???
//
// // 3. Guardada en val
// ???

// %%
def cuadrado(num: Double):Double = num*num

((n : Double) => n*n) (7)

val cuad = (numer : Double) => numer *numer
cuad(7)
// Out:
// defined function cuadrado
// res8_1: Double = 49.0
// cuad: Double => Double = ammonite.$sess.cmd8$Helper$$Lambda/0x00000000169de920@7e5b57aa
// res8_3: Double = 49.0

// %%
cuadrado(7)
// Out:
// res9: Double = 49.0

// %% [markdown]
// 🔹 Ejercicio P9
// Implementa la misma función de tres formas distintas.
//
// La función recibe dos String y los concatena separados por un espacio.
//
// // 1. Con def
// ???
//
// // 2. Anónima pura — pruébala con ("Big", "Data")
// ???
//
// // 3. Guardada en val
// ???
// Salida esperada para ("Big", "Data"):
//
// "Big Data"

// %%
def texto(a: String, b:String): String= s"$a $b"
((pal1: String, pal2:String) => s"$pal1 $pal2") ("Big", "Data")
val frase = (p1: String,p2: String) => s"$p1 $p2"
frase("Big", "Data")
// Out:
// defined function texto
// res11_1: String = "Big Data"
// frase: (String, String) => String = ammonite.$sess.cmd11$Helper$$Lambda/0x00000000169fdaa8@6292e74d
// res11_3: String = "Big Data"

// %%
texto("Big","Data")
// Out:
// res12: String = "Big Data"

// %% [markdown]
// Ejercicio P11 — Análisis de ventas mensuales
// Una empresa registra sus ventas mensuales (en miles de €) durante un año:
//
// val ventas = List(45.2, 38.7, 52.1, 61.0, 58.4, 70.3,
//                   66.9, 72.5, 55.8, 49.3, 41.6, 80.2)
// val meses  = List("Ene","Feb","Mar","Abr","May","Jun",
//                   "Jul","Ago","Sep","Oct","Nov","Dic")
// Usa zip para emparejar cada mes con su venta.
// Imprime los tres meses con mayor venta (usa .sortBy y .take).
// Calcula e imprime la venta total anual y la media mensual.
// Imprime cuántos meses superaron la media.

// %%
val ventas = List(45.2, 38.7, 52.1, 61.0, 58.4, 70.3,
                  66.9, 72.5, 55.8, 49.3, 41.6, 80.2)
val meses  = List("Ene","Feb","Mar","Abr","May","Jun",
                  "Jul","Ago","Sep","Oct","Nov","Dic")


val emparejado = meses.zip(ventas) 
println(emparejado)

val top3 = emparejado.sortBy{case(mes,venta)=> -venta}.take(3)
val ventaTotal = ventas.sum
val media = ventaTotal /ventas.size

println(f" la venta total del año fue $ventaTotal y la media mensual fue: $media%.2f")

val mesesBuenos = ventas.count(_>media)
println(s"la cantidad de meses buenos fueron $mesesBuenos meses")
// Out:
// List((Ene,45.2), (Feb,38.7), (Mar,52.1), (Abr,61.0), (May,58.4), (Jun,70.3), (Jul,66.9), (Ago,72.5), (Sep,55.8), (Oct,49.3), (Nov,41.6), (Dic,80.2))
//  la venta total del año fue 692.0 y la media mensual fue: 57,67
// la cantidad de meses buenos fueron 6 meses
// ventas: List[Double] = List(
//   45.2,
//   38.7,
//   52.1,
//   61.0,
//   58.4,
//   70.3,
//   66.9,
//   72.5,
//   55.8,
//   49.3,
//   41.6,
//   80.2
// )
// meses: List[String] = List(
//   "Ene",
//   "Feb",
//   "Mar",
//   "Abr",
//   "May",
//   "Jun",
//   "Jul",
//   "Ago",
//   "Sep",
//   "Oct",
//   "Nov",
//   "Dic"
// )
// emparejado: List[(String, Double)] = List(
//   ("Ene", 45.2),
//   ("Feb", 38.7),
//   ("Mar", 52.1),
//   ("Abr", 61.0),
//   ("May", 58.4),
//   ("Jun", 70.3),
//   ("Jul", 66.9),
//   ("Ago", 72.5),
//   ("Sep", 55.8),
//   ("Oct", 49.3),
//   ("Nov", 41.6),
//   ("Dic", 80.2)
// )
// top3: List[(String, Double)] = List(("Dic", 80.2), ("Ago", 72.5), ("Jun", 70.3))
// ...

// %% [markdown]
// Integra todo lo aprendido en esta sesión y en la sesión anterior. Vas a analizar un pequeño dataset de ventas representado como una List de Tuple3.

// %%
// Dataset: (producto, categoría, importe)
val ventas: List[(String, String, Double)] = List(
  ("Laptop",    "Electrónica", 899.99),
  ("Ratón",     "Electrónica",  29.99),
  ("Mesa",      "Muebles",     249.00),
  ("Teclado",   "Electrónica",  59.99),
  ("Silla",     "Muebles",     199.00),
  ("Monitor",   "Electrónica", 349.99),
  ("Estantería","Muebles",     149.00),
  ("Auriculares","Electrónica",  79.99))
// Out:
// ventas: List[(String, String, Double)] = List(
//   ("Laptop", "Electrónica", 899.99),
//   ("Ratón", "Electrónica", 29.99),
//   ("Mesa", "Muebles", 249.0),
//   ("Teclado", "Electrónica", 59.99),
//   ("Silla", "Muebles", 199.0),
//   ("Monitor", "Electrónica", 349.99),
//   ("Estantería", "Muebles", 149.0),
//   ("Auriculares", "Electrónica", 79.99)
// )

// %%
//numero total de ventas
val ventasTotales = ventas.map{case(p,c,m)=>m}
val total = ventasTotales.sum
// Out:
// ventasTotales: List[Double] = List(
//   899.99,
//   29.99,
//   249.0,
//   59.99,
//   199.0,
//   349.99,
//   149.0,
//   79.99
// )
// total: Double = 2016.95

// %%
// 1. Número total de ventas
println(s"Total de ventas: ${ventas.length}")

// 2. Categorías únicas (usando Set)
val categorias: Set[String] = ventas.map(_._2).toSet
println(s"Categorías: $categorias")

// 3. Importe total por categoría (usando Map)
val totalPorCategoria: Map[String, Double] = ventas
  .groupBy(_._2)
  .view.mapValues(_.map(_._3).sum)
  .toMap

println("\n=== Importe total por categoría ===")
totalPorCategoria.toList.sortBy(-_._2).foreach { case (cat, total) =>
  println(f"  $cat%-15s → $total%8.2f €")
}

// 4. Producto más caro de cada categoría
println("\n=== Producto más caro por categoría ===")
val masCaro: Map[String, String] = ventas
  .groupBy(_._2)
  .view.mapValues(grupo => grupo.maxBy(_._3)._1)
  .toMap

masCaro.foreach { case (cat, prod) =>
  println(s"  $cat → $prod")
}

// 5. Estadísticas globales con Tuple
val importes = ventas.map(_._3)
val (minVenta, maxVenta, mediaVenta) = (importes.min, importes.max, importes.sum / importes.length)

println(f"\n=== Estadísticas globales ===")
println(f"  Venta mínima:  $minVenta%8.2f €")
println(f"  Venta máxima:  $maxVenta%8.2f €")
println(f"  Ticket medio:  $mediaVenta%8.2f €")
println(f"  Facturación:   ${importes.sum}%8.2f €")
// Out:
// Total de ventas: 8
// Categorías: Set(Electrónica, Muebles)
//
// === Importe total por categoría ===
//   Electrónica     →  1419,95 €
//   Muebles         →   597,00 €
//
// === Producto más caro por categoría ===
//   Muebles → Mesa
//   Electrónica → Laptop
//
// === Estadísticas globales ===
//   Venta mínima:     29,99 €
//   Venta máxima:    899,99 €
//   Ticket medio:    252,12 €
//   Facturación:    2016,95 €
// categorias: Set[String] = Set("Electrónica", "Muebles")
// totalPorCategoria: Map[String, Double] = Map(
//   "Muebles" -> 597.0,
//   "Electrónica" -> 1419.95
// )
// masCaro: Map[String, String] = Map(
//   "Muebles" -> "Mesa",
//   "Electrónica" -> "Laptop"
// )
// importes: List[Double] = List(
//   899.99,
//   29.99,
//   249.0,
//   59.99,
//   199.0,
//   349.99,
//   149.0,
//   79.99
// )
// minVenta: Double = 29.99
// maxVenta: Double = 899.99
// mediaVenta: Double = 252.11875

// %% [markdown]
// Una clínica veterinaria lleva el control de las vacunas administradas a sus pacientes. Tienes dos Set[String] con los nombres de los animales que han recibido cada vacuna. Calcula e imprime: los animales que han recibido ambas vacunas, los animales que solo han recibido la vacuna A, los animales que solo han recibido la vacuna B, y el total de animales únicos atendidos en la clínica.

// %%
val vacunaA = Set("Toby", "Luna", "Max", "Nala", "Rocky")
val vacunaB = Set("Luna", "Rocky", "Bella", "Max", "Coco")
// Out:
// vacunaA: Set[String] = HashSet("Rocky", "Luna", "Max", "Toby", "Nala")
// vacunaB: Set[String] = HashSet("Rocky", "Coco", "Bella", "Luna", "Max")

// %%
//animales con ambas vacunas
val ambas = vacunaA.intersect(vacunaB)
val ambas2 = vacunaA & vacunaB
// Out:
// ambas: Set[String] = HashSet("Rocky", "Luna", "Max")
// ambas2: Set[String] = HashSet("Rocky", "Luna", "Max")

// %%
//animales que solo recibieron la vacunaA
val soloA = vacunaA.diff(vacunaB)
val soloA2 = vacunaA -- vacunaB
// Out:
// soloA: Set[String] = HashSet("Toby", "Nala")
// soloA2: Set[String] = HashSet("Toby", "Nala")

// %%
val animalesUnicos = vacunaA.union(vacunaB).size
val totalUnicos = (vacunaA | vacunaB).size
// Out:
// animalesUnicos: Int = 7
// totalUnicos: Int = 7

// %% [markdown]
//  Ejercicio P7..-Una empresa de mensajería registra el estado de sus envíos en un Map[String, String] donde la clave es el código del envío y el valor es su estado actual. Escribe una función llamada consultarEnvio que reciba el mapa y un código de envío y devuelva el estado si existe o el mensaje "Código no encontrado" si no existe. Prueba la función con al menos un código válido y uno inválido.

// %%
val envios = Map(
  "ENV-001" -> "En tránsito",
  "ENV-002" -> "Entregado",
  "ENV-003" -> "En almacén",
  "ENV-004" -> "Devuelto"
)
// Out:
// envios: Map[String, String] = Map(
//   "ENV-001" -> "En tránsito",
//   "ENV-002" -> "Entregado",
//   "ENV-003" -> "En almacén",
//   "ENV-004" -> "Devuelto"
// )

// %%
def consultarEnvio(envios: Map[String, String], codigo: String): String = {
  envios.getOrElse(codigo, "Código no encontrado")
}

// Pruebas
println(s"ENV-003: ${consultarEnvio(envios, "ENV-003")}")
println(s"ENV-009: ${consultarEnvio(envios, "ENV-009")}")
// Out:
// ENV-003: En almacén
// ENV-009: Código no encontrado
// defined function consultarEnvio
